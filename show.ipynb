# %%
import torch
model = torch.load('pretrain_model/IP-Adapter/sdxl_models/ip-adapter_sdxl.bin',map_location='cpu')

# %%
model['image_proj']['proj.weight'].shape
# Out:
# torch.Size([8192, 1280])

# %%
import torch
model = torch.load('checkpoints/sd15_latent_fix_lr_1e-5_a100-without-motion/checkpoint-25000/pytorch_model.bin',map_location='cpu')

# %%
for key in model.keys():
    if 'pos_embed' in key:
        print(key)
# Out:
# down_blocks.0.motion_modules.0.transformer_blocks.0.pos_embed.pe
# down_blocks.0.motion_modules.1.transformer_blocks.0.pos_embed.pe
# down_blocks.1.motion_modules.0.transformer_blocks.0.pos_embed.pe
# down_blocks.1.motion_modules.1.transformer_blocks.0.pos_embed.pe
# down_blocks.2.motion_modules.0.transformer_blocks.0.pos_embed.pe
# down_blocks.2.motion_modules.1.transformer_blocks.0.pos_embed.pe
# down_blocks.3.motion_modules.0.transformer_blocks.0.pos_embed.pe
# down_blocks.3.motion_modules.1.transformer_blocks.0.pos_embed.pe
# up_blocks.0.motion_modules.0.transformer_blocks.0.pos_embed.pe
# up_blocks.0.motion_modules.1.transformer_blocks.0.pos_embed.pe
# up_blocks.0.motion_modules.2.transformer_blocks.0.pos_embed.pe
# up_blocks.1.motion_modules.0.transformer_blocks.0.pos_embed.pe
# up_blocks.1.motion_modules.1.transformer_blocks.0.pos_embed.pe
# up_blocks.1.motion_modules.2.transformer_blocks.0.pos_embed.pe
# up_blocks.2.motion_modules.0.transformer_blocks.0.pos_embed.pe
# ...

# %%
import torch
from safetensors.torch import load_file, save_file

model = load_file('checkpoints/train_sdxl_lora/checkpoint-30000/pytorch_lora_weights.safetensors')

# %%
for key in model.keys():
    print(key)
# Out:
# unet.down_blocks.0.motion_modules.0.transformer_blocks.0.attn1.to_k.lora.down.weight
# unet.down_blocks.0.motion_modules.0.transformer_blocks.0.attn1.to_k.lora.up.weight
# unet.down_blocks.0.motion_modules.0.transformer_blocks.0.attn1.to_out.0.lora.down.weight
# unet.down_blocks.0.motion_modules.0.transformer_blocks.0.attn1.to_out.0.lora.up.weight
# unet.down_blocks.0.motion_modules.0.transformer_blocks.0.attn1.to_q.lora.down.weight
# unet.down_blocks.0.motion_modules.0.transformer_blocks.0.attn1.to_q.lora.up.weight
# unet.down_blocks.0.motion_modules.0.transformer_blocks.0.attn1.to_v.lora.down.weight
# unet.down_blocks.0.motion_modules.0.transformer_blocks.0.attn1.to_v.lora.up.weight
# unet.down_blocks.0.motion_modules.1.transformer_blocks.0.attn1.to_k.lora.down.weight
# unet.down_blocks.0.motion_modules.1.transformer_blocks.0.attn1.to_k.lora.up.weight
# unet.down_blocks.0.motion_modules.1.transformer_blocks.0.attn1.to_out.0.lora.down.weight
# ...

# %%
import json
with open("datasets/Pexels_Human/video_caption.json", 'r') as file:
    all_data = json.load(file)

# %%
len(all_data)
